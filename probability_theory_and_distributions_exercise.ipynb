# %%
# import numpy
import numpy as np

# import matplotlib.pyplot
import matplotlib.pyplot as plt

# import Counter
from collections import Counter

# use style 'fivethirtyeight' (optional)
plt.style.use('fivethirtyeight')

# %% [markdown]
# #### Create function `perform_bernoulli_trial` with parameters n and p
#
# PARAMS:
# - n (int) - number of trials
# - p (float) - probability of success
#
# RETURNS:
# - n_success (int) - number of successes

# %%
def perform_bernoulli_trial():
    print("How many trials?")
    n = int(input())
    print("Probability of success?")
    p = float(input())
    n_success = np.random.binomial(n,p)
    return n_success
perform_bernoulli_trial()
# Out:
# How many trials?
#  2
# Probability of success?
#  0.3
# 0

# %% [markdown]
# #### Use function `perform_bernoulli_trial` with inputs n = 100, p = 0.5

# %%
perform_bernoulli_trial()
# Out:
# How many trials?
#  100
# Probability of success?
#  0.5
# 55

# %% [markdown]
# #### Call function _perform_bernoulli_trial_ 1000-times with same parameters as before and store the result in `successes_list`

# %%
def perform_bernouli_trials_set(n,p):
    n=int(n)
    p=float(p)
    n_success = np.random.binomial(n,p)
    return n_success

i=0
successes_list=[]
while i <= 1000:
    perform_bernouli_trials_set(100,0.5)
    i+=1
    successes_list.append(perform_bernouli_trials_set(100,0.5))
successes_list
# Out:
# [54,
#  54,
#  44,
#  54,
#  48,
#  51,
#  58,
#  52,
#  42,
#  43,
#  50,
#  44,
#  61,
#  46,
#  53,
#  36,
#  47,
#  43,
#  57,
#  43,
#  45,
#  48,
#  49,
#  50,
#  53,
#  54,
#  57,
#  39,
#  55,
#  53,
#  49,
#  53,
#  49,
#  53,
#  59,
#  45,
#  46,
#  44,
#  43,
#  51,
#  51,
#  45,
#  47,
#  46,
#  43,
#  46,
#  55,
#  47,
#  45,
#  56,
#  48,
#  47,
#  45,
#  55,
#  52,
#  55,
#  45,
#  48,
#  51,
#  50,
#  55,
#  52,
#  63,
#  58,
#  55,
#  56,
#  46,
#  51,
#  43,
#  50,
#  44,
#  50,
#  46,
#  44,
#  44,
#  47,
#  49,
#  53,
#  53,
#  44,
#  51,
#  42,
#  46,
#  51,
#  51,
#  56,
#  50,
#  46,
#  55,
#  55,
#  49,
#  54,
#  57,
#  58,
#  51,
#  49,
#  49,
#  52,
#  53,
#  50,
#  50,
#  39,
#  45,
#  47,
#  48,
#  50,
#  49,
#  56,
#  48,
#  46,
#  55,
#  46,
#  46,
#  55,
#  44,
#  55,
#  53,
#  56,
#  53,
#  51,
#  53,
#  53,
#  49,
#  51,
#  46,
#  56,
#  50,
#  40,
#  50,
#  47,
#  46,
#  45,
#  48,
#  50,
#  50,
#  42,
#  55,
#  50,
#  43,
#  54,
#  42,
#  53,
#  51,
#  52,
#  50,
#  44,
#  58,
#  49,
#  44,
#  56,
#  49,
#  53,
#  53,
#  51,
#  48,
#  56,
#  49,
#  55,
#  54,
#  49,
#  53,
#  44,
#  54,
#  51,
#  47,
#  45,
#  44,
#  42,
#  60,
#  43,
#  52,
#  52,
#  44,
#  48,
#  59,
#  51,
#  52,
#  56,
#  53,
#  55,
#  44,
#  57,
#  48,
#  44,
#  47,
#  53,
#  56,
#  53,
#  50,
#  51,
#  42,
#  56,
#  52,
#  50,
#  45,
#  42,
#  44,
#  47,
#  42,
#  51,
#  52,
#  51,
#  46,
#  50,
#  53,
#  61,
#  43,
#  49,
#  49,
#  54,
#  47,
#  55,
#  53,
#  56,
#  46,
#  48,
#  51,
#  51,
#  53,
#  46,
#  48,
#  48,
#  56,
#  52,
#  61,
#  45,
#  51,
#  44,
#  50,
#  53,
#  50,
#  46,
#  49,
#  53,
#  52,
#  44,
#  50,
#  50,
#  57,
#  51,
#  58,
#  45,
#  54,
#  53,
#  43,
#  48,
#  39,
#  51,
#  35,
#  54,
#  60,
#  55,
#  50,
#  54,
#  49,
#  49,
#  54,
#  54,
#  51,
#  53,
#  52,
#  40,
#  55,
#  51,
#  45,
#  46,
#  50,
#  61,
#  43,
#  48,
#  45,
#  59,
#  41,
#  47,
#  52,
#  54,
#  51,
#  45,
#  56,
#  54,
#  43,
#  48,
#  45,
#  52,
#  44,
#  53,
#  54,
#  53,
#  58,
#  47,
#  53,
#  46,
#  48,
#  50,
#  48,
#  43,
#  50,
#  49,
#  57,
#  49,
#  52,
#  43,
#  56,
#  49,
#  49,
#  51,
#  53,
#  49,
#  54,
#  47,
#  45,
#  51,
#  46,
#  45,
#  44,
#  54,
#  49,
#  58,
#  48,
#  53,
#  51,
#  47,
#  49,
#  56,
#  49,
#  47,
#  51,
#  46,
#  52,
#  47,
#  54,
#  55,
#  49,
#  53,
#  47,
#  57,
#  54,
#  53,
#  54,
#  47,
#  55,
#  49,
#  52,
#  61,
#  43,
#  44,
#  51,
#  48,
#  54,
#  50,
#  42,
#  48,
#  58,
#  42,
#  52,
#  58,
#  48,
#  49,
#  52,
#  55,
#  53,
#  58,
#  49,
#  45,
#  54,
#  52,
#  44,
#  46,
#  45,
#  51,
#  40,
#  49,
#  44,
#  48,
#  46,
#  50,
#  47,
#  54,
#  55,
#  48,
#  55,
#  50,
#  44,
#  43,
#  41,
#  52,
#  43,
#  54,
#  40,
#  44,
#  52,
#  39,
#  52,
#  47,
#  44,
#  51,
#  49,
#  47,
#  51,
#  45,
#  52,
#  42,
#  42,
#  44,
#  50,
#  54,
#  48,
#  50,
#  52,
#  49,
#  47,
#  46,
#  60,
#  57,
#  56,
#  55,
#  52,
#  47,
#  49,
#  60,
#  51,
#  52,
#  50,
#  47,
#  53,
#  51,
#  45,
#  43,
#  45,
#  50,
#  46,
#  49,
#  46,
#  52,
#  58,
#  57,
#  49,
#  54,
#  53,
#  54,
#  55,
#  47,
#  42,
#  49,
#  51,
#  51,
#  44,
#  53,
#  47,
#  43,
#  43,
#  46,
#  52,
#  54,
#  52,
#  63,
#  51,
#  45,
#  45,
#  45,
#  56,
#  53,
#  50,
#  58,
#  52,
#  49,
#  49,
#  62,
#  42,
#  54,
#  50,
#  43,
#  59,
#  45,
#  45,
#  56,
#  55,
#  49,
#  46,
#  51,
#  45,
#  47,
#  56,
#  56,
#  57,
#  49,
#  48,
#  48,
#  48,
#  42,
#  51,
#  55,
#  45,
#  43,
#  45,
#  53,
#  44,
#  52,
#  56,
#  49,
#  47,
#  48,
#  56,
#  49,
#  56,
#  49,
#  47,
#  56,
#  57,
#  57,
#  48,
#  48,
#  53,
#  44,
#  48,
#  49,
#  50,
#  45,
#  54,
#  54,
#  56,
#  50,
#  54,
#  52,
#  53,
#  57,
#  58,
#  43,
#  51,
#  51,
#  40,
#  53,
#  47,
#  55,
#  48,
#  49,
#  55,
#  54,
#  51,
#  49,
#  52,
#  60,
#  42,
#  47,
#  44,
#  45,
#  44,
#  46,
#  46,
#  48,
#  52,
#  55,
#  52,
#  44,
#  52,
#  56,
#  45,
#  52,
#  53,
#  41,
#  43,
#  52,
#  61,
#  47,
#  52,
#  49,
#  51,
#  53,
#  39,
#  59,
#  46,
#  56,
#  47,
#  47,
#  50,
#  42,
#  47,
#  42,
#  53,
#  50,
#  55,
#  55,
#  49,
#  52,
#  53,
#  51,
#  45,
#  49,
#  48,
#  45,
#  52,
#  52,
#  50,
#  49,
#  50,
#  56,
#  40,
#  45,
#  46,
#  44,
#  54,
#  50,
#  53,
#  56,
#  55,
#  49,
#  49,
#  44,
#  48,
#  55,
#  45,
#  50,
#  46,
#  55,
#  49,
#  52,
#  47,
#  52,
#  42,
#  56,
#  47,
#  46,
#  53,
#  51,
#  47,
#  60,
#  51,
#  50,
#  55,
#  47,
#  45,
#  48,
#  53,
#  39,
#  45,
#  54,
#  49,
#  54,
#  43,
#  50,
#  50,
#  42,
#  47,
#  54,
#  49,
#  43,
#  43,
#  50,
#  45,
#  48,
#  46,
#  45,
#  52,
#  43,
#  43,
#  57,
#  51,
#  47,
#  57,
#  54,
#  57,
#  56,
#  44,
#  52,
#  44,
#  41,
#  48,
#  57,
#  50,
#  48,
#  48,
#  52,
#  56,
#  47,
#  56,
#  55,
#  55,
#  57,
#  49,
#  52,
#  55,
#  48,
#  58,
#  52,
#  54,
#  62,
#  58,
#  50,
#  47,
#  53,
#  49,
#  50,
#  50,
#  49,
#  43,
#  50,
#  52,
#  56,
#  58,
#  42,
#  42,
#  58,
#  57,
#  53,
#  52,
#  51,
#  52,
#  49,
#  45,
#  48,
#  60,
#  50,
#  55,
#  42,
#  50,
#  45,
#  55,
#  51,
#  49,
#  48,
#  50,
#  61,
#  52,
#  46,
#  50,
#  41,
#  48,
#  54,
#  55,
#  49,
#  50,
#  56,
#  54,
#  50,
#  48,
#  55,
#  53,
#  51,
#  47,
#  53,
#  46,
#  44,
#  48,
#  48,
#  53,
#  58,
#  61,
#  45,
#  61,
#  52,
#  47,
#  47,
#  53,
#  48,
#  42,
#  57,
#  50,
#  53,
#  49,
#  52,
#  54,
#  51,
#  50,
#  49,
#  40,
#  50,
#  47,
#  48,
#  56,
#  55,
#  45,
#  51,
#  46,
#  47,
#  56,
#  45,
#  45,
#  50,
#  51,
#  51,
#  51,
#  47,
#  54,
#  50,
#  58,
#  53,
#  53,
#  48,
#  45,
#  60,
#  46,
#  58,
#  47,
#  36,
#  54,
#  50,
#  58,
#  45,
#  47,
#  48,
#  49,
#  51,
#  46,
#  46,
#  48,
#  47,
#  51,
#  51,
#  59,
#  39,
#  51,
#  45,
#  41,
#  47,
#  53,
#  46,
#  45,
#  47,
#  53,
#  55,
#  49,
#  50,
#  55,
#  54,
#  46,
#  52,
#  40,
#  40,
#  50,
#  50,
#  52,
#  45,
#  52,
#  41,
#  60,
#  51,
#  47,
#  45,
#  46,
#  53,
#  52,
#  42,
#  51,
#  51,
#  52,
#  48,
#  45,
#  54,
#  53,
#  49,
#  51,
#  51,
#  47,
#  52,
#  44,
#  54,
#  54,
#  46,
#  46,
#  50,
#  44,
#  51,
#  47,
#  49,
#  47,
#  57,
#  47,
#  52,
#  54,
#  48,
#  61,
#  50,
#  54,
#  54,
#  50,
#  51,
#  45,
#  55,
#  59,
#  50,
#  44,
#  54,
#  55,
#  59,
#  53,
#  46,
#  45,
#  51,
#  49,
#  50,
#  51,
#  50,
#  59,
#  52,
#  52,
#  52,
#  48,
#  55,
#  51,
#  55,
#  51,
#  37,
#  50,
#  56,
#  46,
#  41,
#  56,
#  51,
#  41,
#  46,
#  62,
#  46,
#  52,
#  51,
#  55,
#  54,
#  52,
#  58,
#  58,
#  46,
#  48,
#  58,
#  49,
#  51,
#  48,
#  48,
#  52,
#  45,
#  47,
#  55,
#  58,
#  51,
#  45,
#  52,
#  55,
#  50,
#  54,
#  53,
#  55,
#  54,
#  46,
#  52,
#  56,
#  46,
#  41,
#  59,
#  43,
#  50,
#  52,
#  55,
#  42,
#  48,
#  47,
#  53,
#  52,
#  53,
#  44,
#  46,
#  51,
#  51,
#  49,
#  56,
#  48,
#  51,
#  57,
#  50,
#  60,
#  56,
#  52,
#  52,
#  45,
#  46,
#  54,
#  57,
#  44,
#  46,
#  49,
#  53,
#  52,
#  47,
#  43,
#  53,
#  47,
#  52,
#  53,
#  49,
#  50,
#  48,
#  48,
#  56,
#  59,
#  51,
#  42,
#  51,
#  56,
#  51,
#  50,
#  54,
#  51,
#  47,
#  ...]

# %% [markdown]
# #### Count occurence of each number from `successes_list` using Counter and store the result in `count_occurence`
#
# You can find for more info about Counter [**here**](https://docs.python.org/2/library/collections.html#collections.Counter).

# %%
count_occurence = Counter(successes_list)
count_occurence
# Out:
# Counter({54: 59,
#          44: 43,
#          48: 63,
#          51: 83,
#          58: 25,
#          52: 78,
#          42: 27,
#          43: 32,
#          50: 79,
#          61: 10,
#          46: 57,
#          53: 69,
#          36: 2,
#          47: 65,
#          57: 23,
#          45: 60,
#          49: 73,
#          39: 7,
#          55: 54,
#          59: 11,
#          56: 45,
#          63: 2,
#          40: 9,
#          60: 10,
#          35: 1,
#          41: 10,
#          62: 3,
#          37: 1})

# %% [markdown]
# #### Count the probability for each number from `count_occurence` and store the result in `probas`

# %%
count = sum(count_occurence.values())
probas = []
for y in count_occurence:
    p = count_occurence[y]/count*100
    probas.append('{}:{}'.format(count_occurence[y],p))
probas
# Out:
# ['59:5.894105894105895',
#  '43:4.295704295704296',
#  '63:6.293706293706294',
#  '83:8.291708291708291',
#  '25:2.4975024975024978',
#  '78:7.792207792207792',
#  '27:2.697302697302697',
#  '32:3.196803196803197',
#  '79:7.892107892107893',
#  '10:0.999000999000999',
#  '57:5.694305694305695',
#  '69:6.893106893106893',
#  '2:0.1998001998001998',
#  '65:6.493506493506493',
#  '23:2.2977022977022976',
#  '60:5.994005994005994',
#  '73:7.292707292707293',
#  '7:0.6993006993006993',
#  '54:5.394605394605394',
#  '11:1.098901098901099',
#  '45:4.495504495504496',
#  '2:0.1998001998001998',
#  '9:0.8991008991008992',
#  '10:0.999000999000999',
#  '1:0.0999000999000999',
#  '10:0.999000999000999',
#  '3:0.2997002997002997',
#  '1:0.0999000999000999']

# %% [markdown]
# Below you have some information about how to do plots in Python. We will be covering all of this during the bootcamp. But you can find these basics here so we can visualize the distributions.

# %%
# plot distribution (PMF) of 'succes_list'
plt.scatter(x=count_occurence.keys(), y=probas)
plt.xlabel('number of succeess out of 100')
plt.ylabel('probability')
# Show the plot
plt.show()

# %% [markdown]
# #### Generate 100000 numbers from uniform distribution with parameters a = 1, b = 6

# %%
uniform = np.random.normal(1, 6, size = 100000)
uniform
# Out:
# array([-3.77123   ,  9.13024158,  6.96801644, ...,  2.91575463,
#        -6.4938036 , -2.69464137])

# %%
# plot histogram of uniform distribution with paramsdensity=True, bins=6
plt.hist(uniform, density=True, bins=6)
plt.ylabel('density')
plt.xlabel('value')
plt.show()

# %% [markdown]
# #### Check the mean of uniform data (using NumPy)

# %%
uniform.mean()
# Out:
# 0.967735219274489

# %% [markdown]
# #### Generate 100000 numbers from exponential distribution with parameter beta = 0.5
#
# The exponential distribution is sometimes parametrized in terms of the scale parameter **β = 1/λ**. We were reading about the **λ** in the previous reading.

# %%
exponential = np.random.exponential(0.5,size=100000)
exponential
# Out:
# array([0.17460703, 1.36954154, 1.20278982, ..., 0.72539457, 0.26018713,
#        0.0591515 ])

# %% [markdown]
# #### Plot histogram of exponential distribution with params `density=True`, `bins=100`

# %%
plt.hist(exponential, density=True, bins=100)
plt.ylabel('density')
plt.xlabel('value')
plt.show()

# %% [markdown]
# #### Check the mean of exponential data

# %%
exponential.mean()
# Out:
# 0.4996140383242292
